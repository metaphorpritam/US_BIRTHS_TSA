# %%
from datasets import load_dataset
import duckdb as ddb
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from datetime import datetime
import utilities.wind_farm_analysis as wind


print("✓ All imports successful")
# Out:
# ✓ All imports successful

# %%
# Load dataset
ds = load_dataset("thuml/UTSD", "UTSD-2G")
df = pd.DataFrame(ds['train'])

# Filter for smart meter data
con = ddb.connect()
# Out:
# Resolving data files:   0%|          | 0/320 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/80 [00:00<?, ?it/s]

# %%
us_births_df = con.execute("""
    SELECT * FROM df WHERE item_id LIKE '%birth%';
""").fetch_df()

print(f"Loaded {len(us_births_df)} customer time series")
us_births_df.head(n = 5)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Loaded 1 customer time series
#                         item_id                          start  \
# 0  Nature_us_births_dataset_0_0  1969-01-01T00:00:00.000000000
#
#                              end freq  \
# 0  1988-12-31T00:00:00.000000000    D
#
#                                               target
# 0  [8486.0, 9002.0, 9542.0, 8960.0, 8390.0, 9560....

# %%
row = us_births_df.iloc[0]
print(len(row['target']))

interval_info = wind.detect_time_interval(row)
print(f"Interval: {interval_info['interval_str']}")
# Out:
# 7305
# Interval: 24.0h
